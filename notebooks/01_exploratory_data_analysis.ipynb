# %% [markdown]
# # Análise Exploratória

# %% [markdown]
# ## Configurações

# %%
# configurações
import importlib #quando necessário reimportar pacotes

import sys
sys.path.append("../")
sys.path.append("../ml-project-template")

import config
import utils
import data_manager
import kaggle_manager
import eda

# %%
# inicializa o manager para download de dados do kaggle
kaggle_manager = kaggle_manager.KaggleManager()
kaggle_manager.check_authentication()
# Out:
#  Autenticação bem sucedida

# %%
#kaggle_manager.force_download = True
kaggle_manager.download_database(url = 'saurabhbadole/bank-customer-churn-prediction-dataset')
# Out:
#  Verificando existência de dados da url saurabhbadole/bank-customer-churn-prediction-dataset
#  Iniciando download...
# Dataset URL: https://www.kaggle.com/datasets/saurabhbadole/bank-customer-churn-prediction-dataset
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 262k/262k [00:00<00:00, 72.0MB/s]
#  Arquivo baixado: bank-customer-churn-prediction-dataset.zip
#  Extraindo arquivos...
#  Arquivo zip removido
#  Download concluído! Arquivos:
#    - Churn_Modelling.csv
#  Dados em: D:\mba\Data Science e Analytics (USP-Esalq)\99 - TCC\Projeto\notebooks\..\data\raw

# %%
dm = data_manager.DataManager()
raw_df = dm.load_raw_data(['Churn_Modelling.csv'])
# Out:
# Churn_Modelling.csv - formato: (10000, 14)

# %%
raw_train_df, raw_test_df = dm.split_train_test(raw_df)

# %%
dm.save_raw_data(train_df = raw_train_df, test_df = raw_test_df)
# Out:
#  Dados salvos em: D:\mba\Data Science e Analytics (USP-Esalq)\99 - TCC\Projeto\notebooks\..\data\raw

# %%
raw_train_df
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 8769       8770    15646262         Ross          622    France    Male   31
# 3920       3921    15620268      Thomson          634   Germany    Male   43
# 3983       3984    15814092         Wang          626    France  Female   44
# 3944       3945    15794792      Golubev          612    France  Female   31
# 3279       3280    15670615  Castiglione          652     Spain    Male   37
# ...         ...         ...          ...          ...       ...     ...  ...
# 3218       3219    15774872       Joslin          663    France    Male   36
# 4134       4135    15684147      Palerma          678    France    Male   43
# 4453       4454    15775756  Alexandrova          809   Germany    Male   33
# 9346       9347    15805681  Chamberlain          716    France    Male   41
# 8152       8153    15725772        Ch'in          654     Spain  Female   36
#
# ...

# %%
raw_test_df
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 4559       4560    15668248       Quinn          528   Germany  Female   62
# 2531       2532    15752300      Sagese          607   Germany    Male   47
# 7504       7505    15587038   Ogochukwu          654     Spain  Female   32
# 4879       4880    15777045       Price          783     Spain  Female   44
# 6418       6419    15801924      Browne          754     Spain  Female   27
# ...         ...         ...         ...          ...       ...     ...  ...
# 7997       7998    15601719  Fiorentino          465   Germany    Male   24
# 2782       2783    15775234      Laurie          646    France    Male   24
# 8552       8553    15749345     Simpson          468    France  Female   22
# 5562       5563    15614361        Liao          620     Spain    Male   42
# 4685       4686    15646490       Duffy          537     Spain    Male   42
#
# ...

# %% [markdown]
# ## Estatísticas descritivas

# %%
eda.basic_info_dataset(raw_train_df, "Dados Brutos - Treino")
# Out:
# ***Dados Brutos - Treino***
#
# Formato: (8000, 14)
#
# Colunas: ['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
#
# Nulos:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64
#
# NA:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
eda.basic_info_dataset(raw_test_df, "Dados Brutos - Teste")
# Out:
# ***Dados Brutos - Teste***
#
# Formato: (2000, 14)
#
# Colunas: ['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
#
# Nulos:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64
#
# NA:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
eda.get_summary_statistics(raw_df, "Dados Brutos - Base Completa")
# Out:
#  Análise Descritiva: Dados Brutos - Base Completa
#
#  Target:
# <style type="text/css">
# </style>
# <table id="T_17421">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17421_level0_col0" class="col_heading level0 col0" >Exited(int64)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17421_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_17421_row0_col0" class="data row0 col0" >10.000,00</td>
#     </tr>
#     <tr>
#       <th id="T_17421_level0_row1" class="row_heading level0 row1" >nunique</th>
#       <td id="T_17421_row1_col0" class="data row1 col0" >2,00</td>
#     </tr>
#     <tr>
#       <th id="T_17421_level0_row2" class="row_heading level0 row2" >mode</th>
#       <td id="T_17421_row2_col0" class="data row2 col0" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_17421_level0_row3" class="row_heading level0 row3" >value_counts</th>
# ...

# %%
eda.get_summary_statistics(raw_train_df, "Dados Brutos - Treino")
# Out:
#  Análise Descritiva: Dados Brutos - Treino
#
#  Target:
# <style type="text/css">
# </style>
# <table id="T_9bc52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bc52_level0_col0" class="col_heading level0 col0" >Exited(int64)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bc52_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_9bc52_row0_col0" class="data row0 col0" >8.000,00</td>
#     </tr>
#     <tr>
#       <th id="T_9bc52_level0_row1" class="row_heading level0 row1" >nunique</th>
#       <td id="T_9bc52_row1_col0" class="data row1 col0" >2,00</td>
#     </tr>
#     <tr>
#       <th id="T_9bc52_level0_row2" class="row_heading level0 row2" >mode</th>
#       <td id="T_9bc52_row2_col0" class="data row2 col0" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_9bc52_level0_row3" class="row_heading level0 row3" >value_counts</th>
# ...

# %%
eda.get_summary_statistics(raw_test_df, "Dados Brutos - Teste")
# Out:
#  Análise Descritiva: Dados Brutos - Teste
#
#  Target:
# <style type="text/css">
# </style>
# <table id="T_599b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_599b2_level0_col0" class="col_heading level0 col0" >Exited(int64)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_599b2_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_599b2_row0_col0" class="data row0 col0" >2.000,00</td>
#     </tr>
#     <tr>
#       <th id="T_599b2_level0_row1" class="row_heading level0 row1" >nunique</th>
#       <td id="T_599b2_row1_col0" class="data row1 col0" >2,00</td>
#     </tr>
#     <tr>
#       <th id="T_599b2_level0_row2" class="row_heading level0 row2" >mode</th>
#       <td id="T_599b2_row2_col0" class="data row2 col0" >0,00</td>
#     </tr>
#     <tr>
#       <th id="T_599b2_level0_row3" class="row_heading level0 row3" >value_counts</th>
# ...

# %% [markdown]
# ## Visualizações

# %%
eda.plot_boxplot_by_target(raw_train_df, "Dados Brutos - Treino")

# %%
eda.plot_boxplot_by_target(raw_test_df, "Dados Brutos - Teste")

# %%
eda.plot_boxplot_comparative(raw_train_df, raw_test_df, "Dados Brutos - Treino", "Dados Brutos - Teste")

# %%
eda.plot_histogram_by_target(raw_train_df, "Dados Brutos - Treino")

# %%
eda.plot_histogram_by_target(raw_test_df, "Dados Brutos - Test")

# %%
eda.plot_histogram_comparative(raw_train_df, raw_test_df, "Dados Brutos - Treino", "Dados Brutos - Teste")

# %%
eda.plot_violin_by_target(raw_train_df, "Dados Brutos - Treino")

# %%
eda.plot_violin_comparative(raw_train_df, raw_test_df, "Dados Brutos - Treino", "Dados Brutos - Teste")

# %%
eda.plot_barplot_by_target(raw_train_df, "Dados Brutos - Treino")

# %%
eda.plot_barplot_by_target(raw_test_df, "Dados Brutos - Teste")

# %%
eda.plot_barplot_comparative(raw_train_df, raw_test_df, "Dados Brutos - Treino", "Dados Brutos - Teste")
